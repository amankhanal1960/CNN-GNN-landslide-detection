# %%
from pathlib import Path
import geopandas as gpd

root = Path(r"E:\Major project")
gdf = gpd.read_file(root/"Datasets"/"asian"/"DataFile1 - 12838ASMInventory.shp")
print(gdf.columns)
# Out:
# Index(['Pre_Sat', 'Post_Sat', 'Reactivate', 'Year', 'Shape_Leng', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\aman\anaconda3\envs\tf_gpu_final\lib\site-packages (from geopandas) (1.24.3)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.13.0-cp310-cp310-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in c:\users\aman\anaconda3\envs\tf_gpu_final\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\aman\anaconda3\envs\tf_gpu_final\lib\site-packages (from geopandas) (2.3.3)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp310-cp310-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aman\appdata\roaming\python\python310\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aman\anaconda3\envs\tf_gpu_final\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aman\anaconda3\envs\tf_gpu_final\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.3)
# Requirement already satisfied: certifi in c:\users\aman\anaconda3\envs\tf_gpu_final\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\aman\anaconda3\envs\tf_gpu_final\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.4-py3-none-any.whl (343 kB)
# Downloading pyogrio-0.13.0-cp310-cp310-win_amd64.whl (23.9 MB)
#    ---------------------------------------- 0.0/23.9 MB ? eta -:--:--
#    ---- ----------------------------------- 2.6/23.9 MB 12.5 MB/s eta 0:00:02
#    ------------------ --------------------- 11.0/23.9 MB 26.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 20.7/23.9 MB 33.5 MB/s eta 0:00:01
#    ---------------------------------------- 23.9/23.9 MB 31.5 MB/s  0:00:00
# Downloading pyproj-3.7.1-cp310-cp310-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 29.5 MB/s  0:00:00
# Downloading shapely-2.1.2-cp310-cp310-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 23.5 MB/s  0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
#
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------- ----------------------------- 1/4 [pyproj]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ---------------------------------------- 4/4 [geopandas]
#
# Successfully installed geopandas-1.1.4 pyogrio-0.13.0 pyproj-3.7.1 shapely-2.1.2
